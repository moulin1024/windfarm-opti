# %%
import numpy as np
import matplotlib.pyplot as plt

import scipy.ndimage as ndimage
power = np.load('power_map.npy')
print(power)
# Out:
# [[-0.6711996  -0.68021686 -0.67563103 ... -0.66031473 -0.65757449
#   -0.65934745]
#  [-0.6761164  -0.6782746  -0.68025262 ... -0.66460757 -0.66648426
#   -0.66139784]
#  [-0.68913098 -0.6824795  -0.68589508 ... -0.67141455 -0.67081314
#   -0.66697798]
#  ...
#  [-0.73758685 -0.74726974 -0.74709881 ... -0.77772477 -0.7727454
#   -0.77123927]
#  [-0.74124784 -0.74066914 -0.75312542 ... -0.77158537 -0.77033457
#   -0.76234176]
#  [-0.73196386 -0.74243217 -0.74690561 ... -0.76779995 -0.7685067
#   -0.75893312]]

# %%
x = np.linspace(0,31,32)
y = np.linspace(0,31,32)
XX,YY = np.meshgrid(x,y)

plt.contourf(XX,YY,-power,100)
plt.axis('equal')

# plt.plot(p_history[:,1],p_history[:,0])
# plt.plot(p_history2[:,1],p_history2[:,0])
plt.colorbar()
plt.show()


Z2 = ndimage.gaussian_filter(Z, sigma=1.0, order=0)
